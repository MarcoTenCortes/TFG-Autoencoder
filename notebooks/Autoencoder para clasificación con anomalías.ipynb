# %% [markdown]
# # Detección de anomalías con Autoencoder

# %% [markdown]
# La __detección de anomalías__ es una técnica utilizada en el análisis de datos para identificar patrones inusuales o atípicos. A lo largo de este Notebook se mostrará cómo utilizaran diferentes herramientas para su detección.

# %% [markdown]
# Utilizaremos el famoso dataset conocido cómo _Breast Cancer Wisconsin_.
# Puedes ver más información sobre el dataset en https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic

# %% [markdown]
# ## Carga y Análisis de los datos

# %% [markdown]
# Afortunadamente el repositorio datasets de sklearn incorpora el load_breast_cancer, por lo que podremos cargarlo directamente

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
dataset = load_breast_cancer(as_frame=True)
data = dataset.frame

# %% [markdown]
# Podemos cómo en este caso las clases posibles para los ejemplos son "malignant" o "benign".

# %%
dataset.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %% [markdown]
# Usando la función feature_names seguida de la función size podemos ver la cantidad de atributos o características cada ejemplo, que en este caso consta de 30.

# %%
dataset.feature_names.size
# Out:
# 30

# %% [markdown]
# Podemos ver los datos de nuestro conjunto de datos para poder entenderlos mejor.

# %%
dataset.data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# Con la función describe vemos las estadísticas más relevantes del conjunto de datos (media, desviación típica, valor máximo...)

# %%
data.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension      target
# count               569.000000  569.000000
# mean                  0.083946    0.627417
# std                   0.018061    0.483918
# min                   0.055040    0.000000
# 25%                   0.071460    0.000000
# 50%                   0.080040    1.000000
# 75%                   0.092080    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# Guardamos en X los datos de los atributos así como en y las clase de cada ejemplo.

# %%
X = dataset.data
y = dataset.target

# %% [markdown]
# Es un buen momento de ver que variables son irrelevantes para el modelo. Para ello buscaremos en el siguiente mapa de calor aquellas no tengan correlación con el atributo target (donde veremos un valor 0) y además tenga una alta correlación con cualquier otro atributo, ya que esto nos puede decir que los datos son redundantes.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(13, 13))
sns.heatmap(data.corr(), annot=True, fmt=".1f")
plt.show()

# %%
X = dataset.data.drop("mean fractal dimension", axis=1)

# %% [markdown]
# Podemos visualizar la cantidad de elementos que hay por clase

# %%
data['target'].value_counts().sort_index().get(1,0)
# Out:
# 357

# %%
data['target'].value_counts().sort_index().get(0,0)
# Out:
# 212

# %% [markdown]
# A continuación se muestra de manera gráfica la distribución de los datos del dataset, dividiéndolos por clase

# %%
# Calculamos los conteos de cada clase
conteos = data['target'].value_counts().sort_index()  # Asegurar el orden correcto de las clases

# Crear una figura y un eje
plt.figure(figsize=(6, 4))
# Dibujar un gráfico de barras para cada clase con una etiqueta
plt.bar(0, conteos.get(0, 0), color='#1f77b4', label='0 = Maligno')  # Asumimos que existe la posibilidad de que no haya datos para alguna clase
plt.bar(1, conteos.get(1, 0), color='#ff7f0e', label='1 = Benigno')  # Asumimos que existe la posibilidad de que no haya datos para alguna clase

plt.bar(conteos.index, conteos.values, color=['#1f77b4', '#ff7f0e'])  # Colores azul y naranja

# Agregar título y etiquetas
plt.title('Distribución de clases de tumor')
#plt.xlabel('Clase (0 = Maligno, 1 = Benigno)')
plt.ylabel('Cantidad de ejemplos')

# Configurar las etiquetas del eje x para que muestren claramente qué representa cada barra
plt.xticks([0, 1], ['0 = Maligno', '1 = Benigno'])
plt.legend(title='Leyenda')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# Como podemos ver en la distribución de los datos, no nos encontramos con un caso __anómalo__, así que deberemos recrearlo.

# %% [markdown]
# ## Modificación del conjunto de datos

# %% [markdown]
# Cómo queremos detectar casos anómalos y en este caso la distribución de los ejemplos no cumple con esta condición deberemos modificar la cantidad de datos. Para ello escogeremos un porcentaje de casos malignos que sea anómalo.

# %%
porcentaje_anomalias = 0.1 # % de instancias malignas

# %% [markdown]
# Creamos máscaras para los datos benignos y los datos malignos, modificamos la proporcionalidades y mezclamos los conjuntos.

# %%
mask = y == 1  # Instancias benignas
X_benignas = X[mask]
X_malignas = X[~mask]
num_malignas = int(porcentaje_anomalias * len(X_benignas))
X_nuevo = np.concatenate([X_malignas[:num_malignas], X_benignas], axis=0)
y_nuevo = np.concatenate([np.zeros(num_malignas), np.ones(len(X_benignas))], axis=0)

# %%
pd.Series(y_nuevo).value_counts()
# Out:
# 1.0    357
# 0.0     35
# Name: count, dtype: int64

# %% [markdown]
# Podemos comprobar que ahora hay un caso anómalo de ejemplos con la clase maligno.

# %%
# Calculamos los conteos de cada clase
conteos = pd.Series(y_nuevo).value_counts().sort_index() # Asegurar el orden correcto de las clases

# Creación de la figura
plt.figure(figsize=(6, 4))
# Dibujar un gráfico de barras para cada clase con una etiqueta
plt.bar(0, conteos.get(0, 0), color='#1f77b4', label='0 = Maligno')  # Asumimos que existe la posibilidad de que no haya datos para alguna clase
plt.bar(1, conteos.get(1, 0), color='#ff7f0e', label='1 = Benigno')  # Asumimos que existe la posibilidad de que no haya datos para alguna clase

plt.bar(conteos.index, conteos.values, color=['#1f77b4', '#ff7f0e'])  # Colores azul y naranja

# Agregar título y etiquetas
plt.title('Distribución de clases de cáncer')
#plt.xlabel('Clase (0 = Maligno, 1 = Benigno)')
plt.ylabel('Cantidad de ejemplos')

# Configurar las etiquetas del eje x para que muestren claramente qué representa cada barra
plt.xticks([0, 1], ['0 = Maligno', '1 = Benigno'])
plt.legend(title='Leyenda')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Preparación del conjunto de entrenamiento

# %% [markdown]
# Dividiremos el conjunto de datos en un conjunto de entrenamiento y otro de validación (o test) para poder entrenar nuestro modelo

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_nuevo, y_nuevo, test_size=0.2, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# Vamos a crear máscaras para dividir los conjuntos de datos según las clases de cada uno de sus ejemplos.

# %%
# Mascaras para identificar las clases en los conjuntos
mask_clase_0_tr = (y_train == 0)
mask_clase_0_v = (y_valid == 0)
mask_clase_0_test = (y_test == 0)
mask_clase_1_tr = (y_train == 1)
mask_clase_1_v = (y_valid == 1)
mask_clase_1_test = (y_test == 1)

# Filtra X para quedarte solo con las instancias de la clase deseada
X_train_clase_0_S = X_train[mask_clase_0_tr]
X_valid_clase_0_S =  X_valid[mask_clase_0_v]
X_test_clase_0_S = X_test[mask_clase_0_test]
X_train_clase_1_S = X_train[mask_clase_1_tr]
X_valid_clase_1_S =  X_valid[mask_clase_1_v]
X_test_clase_1_S = X_test[mask_clase_1_test]

# %% [markdown]
# Existen diferentes modos de normalizar nuestros datos, en nuestro caso utilizaremos StandardScaler para poder normalizar los datos de entrada al modelo.
# Estoy tendrá como resultado que la desviación típica sea 1.

# %%
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
normalizador=StandardScaler().fit(X_train_clase_1_S)
X_train_clase_0=normalizador.transform(X_train_clase_0_S)
X_valid_clase_0=normalizador.transform(X_valid_clase_0_S)
X_test_clase_0=normalizador.transform(X_test_clase_0_S)
X_train_clase_1=normalizador.transform(X_train_clase_1_S)
X_valid_clase_1=normalizador.transform(X_valid_clase_1_S)
X_test_clase_1=normalizador.transform(X_test_clase_1_S)

X_train_norm=normalizador.transform(X_train)
X_valid_norm=normalizador.transform(X_valid)
X_test_norm=normalizador.transform(X_test)

with open('normalizador1.pkl', 'wb') as file:
    pickle.dump(normalizador, file) # Se guarda un fichero con la configuración de normalización

# %% [markdown]
# ## Construcción del Autoencoder

# %% [markdown]
# Comprimiremos la información de los datos de entrada para luego volver a descomprimirla. Para ello crearemos un autoencoder

# %% [markdown]
# <img src="imagenes/autoencoder_architecture.png" alt="Arquitectura del Autoencoder" width="500" height="300"/>

# %% [markdown]
# Escogemos el tamaño de neuronas de cada capa.

# %%
input_dim = X_train_norm.shape[1]
encoding_dim = 16  # Dimensión de la codificación
hidden_dim = 8

# %% [markdown]
# Para construir la estructura usaremos __regularización l1__, para de este modo poder prevenir el sobreajuste. La estructura se dividirá en capas encoder y decoder (codificación y decodificación).

# %%
from keras import regularizers

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD

learning_rate = 1e-2

input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="relu",activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(encoding_dim, activation="relu")(decoder)
decoder = Dense(input_dim, activation="linear")(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.summary()
# Out:
# WARNING:tensorflow:From C:\Users\marco\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\marco\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\marco\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 29)]              0
#
#  dense (Dense)               (None, 16)                480
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 16)                144
#
#  dense_4 (Dense)             (None, 29)                493
#
# =================================================================
# Total params: 1325 (5.18 KB)
# Trainable params: 1325 (5.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Aprendizaje del modelo
# Una vez construido el autoencoder los ajustaremos para que nos de un aprendizaje correcto a nuestro caso, para ello hay que probar con diferentes optimizadores y funciones de perdida. En este caso el optimizador Adam y la función de perdida mse (error cuadrático medio).

# %%
autoencoder.compile(metrics=['accuracy'],optimizer=Adam(), loss='mse')

# %%
from tensorflow.keras import layers, callbacks
from keras.callbacks import ModelCheckpoint, TensorBoard
cp = ModelCheckpoint(filepath="autoencoder55.h5",
                               save_best_only=True,
                               verbose=0)
history = autoencoder.fit(X_train_clase_1, X_train_clase_1, epochs=300, batch_size=128, shuffle=True, validation_data=(X_valid_clase_1, X_valid_clase_1),callbacks=[callbacks.EarlyStopping(monitor="val_loss", patience=20, mode="min")
    ,cp],)
# Out:
# Epoch 1/300
# WARNING:tensorflow:From C:\Users\marco\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 2/2 [==============================] - 1s 139ms/step - loss: 1.0840 - accuracy: 0.0260 - val_loss: 1.0298 - val_accuracy: 0.0000e+00
# Epoch 2/300
# 2/2 [==============================] - 0s 33ms/step - loss: 1.0748 - accuracy: 0.0260 - val_loss: 1.0232 - val_accuracy: 0.0000e+00
# Epoch 3/300
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0670 - accuracy: 0.0260 - val_loss: 1.0175 - val_accuracy: 0.0000e+00
# Epoch 4/300
# 2/2 [==============================] - 0s 33ms/step - loss: 1.0612 - accuracy: 0.0130 - val_loss: 1.0125 - val_accuracy: 0.0172
# Epoch 5/300
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0553 - accuracy: 0.0130 - val_loss: 1.0082 - val_accuracy: 0.0172
# Epoch 6/300
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0503 - accuracy: 0.0173 - val_loss: 1.0046 - val_accuracy: 0.0345
# C:\Users\marco\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 7/300
# 2/2 [==============================] - 0s 32ms/step - loss: 1.
300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8509 - accuracy: 0.1299 - val_loss: 0.8062 - val_accuracy: 0.1552
# Epoch 39/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8422 - accuracy: 0.1385 - val_loss: 0.7986 - val_accuracy: 0.1724
# Epoch 40/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.8335 - accuracy: 0.1429 - val_loss: 0.7910 - val_accuracy: 0.1897
# Epoch 41/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8247 - accuracy: 0.1472 - val_loss: 0.7834 - val_accuracy: 0.1897
# Epoch 42/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8168 - accuracy: 0.1429 - val_loss: 0.7761 - val_accuracy: 0.1897
# Epoch 43/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8079 - accuracy: 0.1472 - val_loss: 0.7688 - val_accuracy: 0.1897
# Epoch 44/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7999 - accuracy: 0.1472 - val_loss: 0.7618 - val_accuracy: 0.1897
# Epoch 45/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7924 - accuracy: 0.1472 - val_loss: 0.7549 - val_accuracy: 0.2069
# Epoch 46/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7847 - accuracy: 0.1429 - val_loss: 0.7482 - val_accuracy: 0.2069
# Epoch 47/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7772 - accuracy: 0.1429 - val_loss: 0.7418 - val_accuracy: 0.2069
# Epoch 48/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7687 - accuracy: 0.1472 - val_loss: 0.7355 - val_accuracy: 0.2069
# Epoch 49/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7613 - accuracy: 0.1385 - val_loss: 0.7293 - val_accuracy: 0.2069
# Epoch 50/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7545 - accuracy: 0.1385 - val_loss: 0.7233 - val_accuracy: 0.2069
# Epoch 51/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7472 - accuracy: 0.1429 - val_loss: 0.7176 - val_accuracy: 0.2069
# Epoch 52/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7401 - accuracy: 0.1342 - val_loss: 0.7120 - val_accuracy: 0.2069
# Epoch 53/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7333 - accuracy: 0.1429 - val_loss: 0.7067 - val_accuracy: 0.2069
# Epoch 54/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7264 - accuracy: 0.1429 - val_loss: 0.7015 - val_accuracy: 0.2069
# Epoch 55/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7197 - accuracy: 0.1472 - val_loss: 0.6964 - val_accuracy: 0.2069
# Epoch 56/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7134 - accuracy: 0.1472 - val_loss: 0.6915 - val_accuracy: 0.2069
# Epoch 57/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7077 - accuracy: 0.1429 - val_loss: 0.6869 - val_accuracy: 0.2069
# Epoch 58/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7010 - accuracy: 0.1472 - val_loss: 0.6823 - val_accuracy: 0.2069
# Epoch 59/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6954 - accuracy: 0.1472 - val_loss: 0.6780 - val_accuracy: 0.2069
# Epoch 60/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6897 - accuracy: 0.1558 - val_loss: 0.6737 - val_accuracy: 0.2069
# Epoch 61/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6834 - accuracy: 0.1515 - val_loss: 0.6694 - val_accuracy: 0.2069
# Epoch 62/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6780 - accuracy: 0.1558 - val_loss: 0.6652 - val_accuracy: 0.2069
# Epoch 63/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6722 - accuracy: 0.1602 - val_loss: 0.6610 - val_accuracy: 0.2069
# Epoch 64/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6667 - accuracy: 0.1602 - val_loss: 0.6568 - val_accuracy: 0.2241
# Epoch 65/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6613 - accuracy: 0.1602 - val_loss: 0.6527 - val_accuracy: 0.2241
# Epoch 66/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6561 - accuracy: 0.1602 - val_loss: 0.6485 - val_accuracy: 0.2241
# Epoch 67/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6508 - accuracy: 0.1645 - val_loss: 0.6445 - val_accuracy: 0.2241
# Epoch 68/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6458 - accuracy: 0.1645 - val_loss: 0.6404 - val_accuracy: 0.2241
# Epoch 69/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.
300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3755 - accuracy: 0.2165 - val_loss: 0.3698 - val_accuracy: 0.2931
# Epoch 132/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3722 - accuracy: 0.2121 - val_loss: 0.3672 - val_accuracy: 0.2759
# Epoch 133/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3692 - accuracy: 0.2208 - val_loss: 0.3648 - val_accuracy: 0.2759
# Epoch 134/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3665 - accuracy: 0.2208 - val_loss: 0.3621 - val_accuracy: 0.2759
# Epoch 135/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3636 - accuracy: 0.2294 - val_loss: 0.3597 - val_accuracy: 0.2759
# Epoch 136/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3608 - accuracy: 0.2338 - val_loss: 0.3573 - val_accuracy: 0.2759
# Epoch 137/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3583 - accuracy: 0.2294 - val_loss: 0.3551 - val_accuracy: 0.2931
# Epoch 138/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3557 - accuracy: 0.2338 - val_loss: 0.3529 - val_accuracy: 0.2931
# Epoch 139/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3533 - accuracy: 0.2294 - val_loss: 0.3508 - val_accuracy: 0.3103
# Epoch 140/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3508 - accuracy: 0.2294 - val_loss: 0.3486 - val_accuracy: 0.3103
# Epoch 141/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3484 - accuracy: 0.2381 - val_loss: 0.3465 - val_accuracy: 0.3103
# Epoch 142/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3463 - accuracy: 0.2468 - val_loss: 0.3444 - val_accuracy: 0.3103
# Epoch 143/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3441 - accuracy: 0.2381 - val_loss: 0.3424 - val_accuracy: 0.3276
# Epoch 144/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3419 - accuracy: 0.2381 - val_loss: 0.3406 - val_accuracy: 0.3276
# Epoch 145/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3399 - accuracy: 0.2424 - val_loss: 0.3386 - val_accuracy: 0.3276
# Epoch 146/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3380 - accuracy: 0.2424 - val_loss: 0.3367 - val_accuracy: 0.3448
# Epoch 147/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3360 - accuracy: 0.2424 - val_loss: 0.3348 - val_accuracy: 0.3621
# Epoch 148/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3342 - accuracy: 0.2468 - val_loss: 0.3331 - val_accuracy: 0.3621
# Epoch 149/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3324 - accuracy: 0.2424 - val_loss: 0.3319 - val_accuracy: 0.3621
# Epoch 150/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3307 - accuracy: 0.2424 - val_loss: 0.3307 - val_accuracy: 0.3621
# Epoch 151/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3290 - accuracy: 0.2424 - val_loss: 0.3296 - val_accuracy: 0.3621
# Epoch 152/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3273 - accuracy: 0.2468 - val_loss: 0.3281 - val_accuracy: 0.3448
# Epoch 153/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3257 - accuracy: 0.2511 - val_loss: 0.3265 - val_accuracy: 0.3276
# Epoch 154/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3241 - accuracy: 0.2511 - val_loss: 0.3247 - val_accuracy: 0.3448
# Epoch 155/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3225 - accuracy: 0.2511 - val_loss: 0.3230 - val_accuracy: 0.3448
# Epoch 156/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3209 - accuracy: 0.2468 - val_loss: 0.3212 - val_accuracy: 0.3448
# Epoch 157/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3193 - accuracy: 0.2511 - val_loss: 0.3196 - val_accuracy: 0.3448
# Epoch 158/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3176 - accuracy: 0.2511 - val_loss: 0.3178 - val_accuracy: 0.3621
# Epoch 159/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3159 - accuracy: 0.2511 - val_loss: 0.3161 - val_accuracy: 0.3621
# Epoch 160/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3143 - accuracy: 0.2511 - val_loss: 0.3148 - val_accuracy: 0.3621
# Epoch 161/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3127 - accuracy: 0.2554 - val_loss: 0.3132 - val_accuracy: 0.3448
# Epoch 162/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3110 - accuracy: 0.2597 - val_loss: 0.3115 - val_accuracy: 0.3621
# Epoch 163/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3093 - accuracy: 0.2554 - val_loss: 0.3099 - val_accuracy: 0.3621
# Epoch 164/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3077 - accuracy: 0.2597 - val_loss: 0.3079 - val_accuracy: 0.3621
# Epoch 165/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3059 - accuracy: 0.2597 - val_loss: 0.3061 - val_accuracy: 0.3621
# Epoch 166/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3042 - accuracy: 0.2468 - val_loss: 0.3045 - val_accuracy: 0.3621
# Epoch 167/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3026 - accuracy: 0.2468 - val_loss: 0.3030 - val_accuracy: 0.3621
# Epoch 168/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3010 - accuracy: 0.2468 - val_loss: 0.3015 - val_accuracy: 0.3448
# Epoch 169/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2993 - accuracy: 0.2424 - val_loss: 0.3000 - val_accuracy: 0.3448
# Epoch 170/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2976 - accuracy: 0.2511 - val_loss: 0.2988 - val_accuracy: 0.3621
# Epoch 171/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2959 - accuracy: 0.2597 - val_loss: 0.2973 - val_accuracy: 0.3621
# Epoch 172/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2941 - accuracy: 0.2554 - val_loss: 0.2960 - val_accuracy: 0.3621
# Epoch 173/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2926 - accuracy: 0.2511 - val_loss: 0.2946 - val_accuracy: 0.3793
# Epoch 174/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2910 - accuracy: 0.2468 - val_loss: 0.2927 - val_accuracy: 0.3793
# Epoch 175/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2892 - accuracy: 0.2511 - val_loss: 0.2908 - val_accuracy: 0.3793
# Epoch 176/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2877 - accuracy: 0.2554 - val_loss: 0.2889 - val_accuracy: 0.3793
# Epoch 177/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2860 - accuracy: 0.2511 - val_loss: 0.2873 - val_accuracy: 0.3966
# Epoch 178/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2844 - accuracy: 0.2511 - val_loss: 0.2858 - val_accuracy: 0.3966
# Epoch 179/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2830 - accuracy: 0.2468 - val_loss: 0.2845 - val_accuracy: 0.3966
# Epoch 180/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2816 - accuracy: 0.2468 - val_loss: 0.2831 - val_accuracy: 0.3966
# Epoch 181/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2801 - accuracy: 0.2468 - val_loss: 0.2818 - val_accuracy: 0.3966
# Epoch 182/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2788 - accuracy: 0.2511 - val_loss: 0.2801 - val_accuracy: 0.3793
# Epoch 183/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2774 - accuracy: 0.2511 - val_loss: 0.2786 - val_accuracy: 0.3793
# Epoch 184/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2761 - accuracy: 0.2511 - val_loss: 0.2772 - val_accuracy: 0.3793
# Epoch 185/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2748 - accuracy: 0.2554 - val_loss: 0.2758 - val_accuracy: 0.3793
# Epoch 186/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2735 - accuracy: 0.2554 - val_loss: 0.2744 - val_accuracy: 0.3793
# Epoch 187/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2723 - accuracy: 0.2511 - val_loss: 0.2730 - val_accuracy: 0.3793
# Epoch 188/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2711 - accuracy: 0.2424 - val_loss: 0.2718 - val_accuracy: 0.3621
# Epoch 189/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2699 - accuracy: 0.2468 - val_loss: 0.2705 - val_accuracy: 0.3621
# Epoch 190/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2688 - accuracy: 0.2424 - val_loss: 0.2694 - val_accuracy: 0.3621
# Epoch 191/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2677 - accuracy: 0.2424 - val_loss: 0.2683 - val_accuracy: 0.3621
# Epoch 192/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2665 - accuracy: 0.2424 - val_loss: 0.2671 - val_accuracy: 0.3966
# Epoch 193/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2655 - accuracy: 0.2468 - val_loss: 0.2660 - val_accuracy: 0.3966
# Epoch 194/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2645 - accuracy: 0.2468 - val_loss: 0.2649 - val_accuracy: 0.3966
# Epoch 195/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2636 - accuracy: 0.2511 - val_loss: 0.2642 - val_accuracy: 0.3966
# Epoch 196/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2625 - accuracy: 0.2468 - val_loss: 0.2634 - val_accuracy: 0.3966
# Epoch 197/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2615 - accuracy: 0.2468 - val_loss: 0.2627 - val_accuracy: 0.3966
# Epoch 198/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2606 - accuracy: 0.2511 - val_loss: 0.2618 - val_accuracy: 0.3966
# Epoch 199/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2597 - accuracy: 0.2511 - val_loss: 0.2605 - val_accuracy: 0.4138
# Epoch 200/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2588 - accuracy: 0.2511 - val_loss: 0.2594 - val_accuracy: 0.4138
# Epoch 201/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2579 - accuracy: 0.2554 - val_loss: 0.2584 - val_accuracy: 0.3966
# Epoch 202/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2571 - accuracy: 0.2554 - val_loss: 0.2575 - val_accuracy: 0.3966
# Epoch 203/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2563 - accuracy: 0.2641 - val_loss: 0.2564 - val_accuracy: 0.4138
# Epoch 204/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2555 - accuracy: 0.2641 - val_loss: 0.2554 - val_accuracy: 0.4138
# Epoch 205/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2547 - accuracy: 0.2641 - val_loss: 0.2546 - val_accuracy: 0.4138
# Epoch 206/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2539 - accuracy: 0.2641 - val_loss: 0.2537 - val_accuracy: 0.4138
# Epoch 207/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2531 - accuracy: 0.2641 - val_loss: 0.2528 - val_accuracy: 0.4310
# Epoch 208/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2524 - accuracy: 0.2684 - val_loss: 0.2519 - val_accuracy: 0.4310
# Epoch 209/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2517 - accuracy: 0.2684 - val_loss: 0.2509 - val_accuracy: 0.4138
# Epoch 210/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2510 - accuracy: 0.2684 - val_loss: 0.2501 - val_accuracy: 0.4310
# Epoch 211/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2503 - accuracy: 0.2727 - val_loss: 0.2496 - val_accuracy: 0.4310
# Epoch 212/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2497 - accuracy: 0.2684 - val_loss: 0.2491 - val_accuracy: 0.4310
# Epoch 213/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2490 - accuracy: 0.2684 - val_loss: 0.2483 - val_accuracy: 0.4138
# Epoch 214/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2483 - accuracy: 0.2684 - val_loss: 0.2476 - val_accuracy: 0.4138
# Epoch 215/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2478 - accuracy: 0.2641 - val_loss: 0.2470 - val_accuracy: 0.3966
# Epoch 216/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2472 - accuracy: 0.2641 - val_loss: 0.2468 - val_accuracy: 0.3966
# Epoch 217/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2464 - accuracy: 0.2641 - val_loss: 0.2465 - val_accuracy: 0.3966
# Epoch 218/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2459 - accuracy: 0.2641 - val_loss: 0.2461 - val_accuracy: 0.3966
# Epoch 219/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2453 - accuracy: 0.2684 - val_loss: 0.2453 - val_accuracy: 0.3966
# Epoch 220/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2447 - accuracy: 0.2684 - val_loss: 0.2445 - val_accuracy: 0.3966
# Epoch 221/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2440 - accuracy: 0.2684 - val_loss: 0.2440 - val_accuracy: 0.3793
# Epoch 222/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2434 - accuracy: 0.2684 - val_loss: 0.2436 - val_accuracy: 0.3966
# Epoch 223/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2429 - accuracy: 0.2771 - val_loss: 0.2434 - val_accuracy: 0.3966
# Epoch 224/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2423 - accuracy: 0.2771 - val_loss: 0.2431 - val_accuracy: 0.3966
# Epoch 225/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2417 - accuracy: 0.2771 - val_loss: 0.2427 - val_accuracy: 0.3966
# Epoch 226/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2412 - accuracy: 0.2771 - val_loss: 0.2422 - val_accuracy: 0.3966
# Epoch 227/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2408 - accuracy: 0.2814 - val_loss: 0.2416 - val_accuracy: 0.4138
# Epoch 228/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2402 - accuracy: 0.2814 - val_loss: 0.2410 - val_accuracy: 0.4138
# Epoch 229/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2397 - accuracy: 0.2814 - val_loss: 0.2406 - val_accuracy: 0.4138
# Epoch 230/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2391 - accuracy: 0.2814 - val_loss: 0.2401 - val_accuracy: 0.4138
# Epoch 231/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2386 - accuracy: 0.2900 - val_loss: 0.2397 - val_accuracy: 0.4138
# Epoch 232/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2381 - accuracy: 0.2900 - val_loss: 0.2394 - val_accuracy: 0.4138
# Epoch 233/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2377 - accuracy: 0.2900 - val_loss: 0.2391 - val_accuracy: 0.4138
# Epoch 234/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2371 - accuracy: 0.2944 - val_loss: 0.2387 - val_accuracy: 0.4138
# Epoch 235/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2366 - accuracy: 0.2944 - val_loss: 0.2383 - val_accuracy: 0.4138
# Epoch 236/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2362 - accuracy: 0.2944 - val_loss: 0.2377 - val_accuracy: 0.3966
# Epoch 237/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2358 - accuracy: 0.2944 - val_loss: 0.2372 - val_accuracy: 0.3966
# Epoch 238/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2353 - accuracy: 0.2900 - val_loss: 0.2366 - val_accuracy: 0.4138
# Epoch 239/300
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2349 - accuracy: 0.2857 - val_loss: 0.2363 - val_accuracy: 0.4138
# Epoch 240/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2344 - accuracy: 0.2857 - val_loss: 0.2358 - val_accuracy: 0.4138
# Epoch 241/300
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2340 - accuracy: 0.2814 - val_loss: 0.2351 - val_accuracy: 0.4138
# Epoch 242/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2336 - accuracy: 0.2814 - val_loss: 0.2346 - val_accuracy: 0.3966
# Epoch 243/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2332 - accuracy: 0.2814 - val_loss: 0.2343 - val_accuracy: 0.3966
# Epoch 244/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2327 - accuracy: 0.2814 - val_loss: 0.2340 - val_accuracy: 0.3966
# Epoch 245/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2323 - accuracy: 0.2771 - val_loss: 0.2337 - val_accuracy: 0.3966
# Epoch 246/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2319 - accuracy: 0.2900 - val_loss: 0.2334 - val_accuracy: 0.3966
# Epoch 247/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2315 - accuracy: 0.3030 - val_loss: 0.2331 - val_accuracy: 0.3966
# Epoch 248/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2311 - accuracy: 0.3074 - val_loss: 0.2328 - val_accuracy: 0.3966
# Epoch 249/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2307 - accuracy: 0.3074 - val_loss: 0.2323 - val_accuracy: 0.3966
# Epoch 250/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2304 - accuracy: 0.3030 - val_loss: 0.2321 - val_accuracy: 0.3966
# Epoch 251/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2300 - accuracy: 0.2987 - val_loss: 0.2317 - val_accuracy: 0.3966
# Epoch 252/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2296 - accuracy: 0.2987 - val_loss: 0.2312 - val_accuracy: 0.3966
# Epoch 253/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2292 - accuracy: 0.2987 - val_loss: 0.2308 - val_accuracy: 0.3966
# Epoch 254/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2289 - accuracy: 0.2987 - val_loss: 0.2308 - val_accuracy: 0.3966
# Epoch 255/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2285 - accuracy: 0.2987 - val_loss: 0.2304 - val_accuracy: 0.3966
# Epoch 256/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.
300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2176 - accuracy: 0.2944 - val_loss: 0.2218 - val_accuracy: 0.4310
# Epoch 288/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2173 - accuracy: 0.2857 - val_loss: 0.2214 - val_accuracy: 0.4310
# Epoch 289/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2169 - accuracy: 0.2900 - val_loss: 0.2210 - val_accuracy: 0.4310
# Epoch 290/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2166 - accuracy: 0.2987 - val_loss: 0.2207 - val_accuracy: 0.4310
# Epoch 291/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2164 - accuracy: 0.2944 - val_loss: 0.2206 - val_accuracy: 0.4138
# Epoch 292/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2160 - accuracy: 0.3030 - val_loss: 0.2203 - val_accuracy: 0.4138
# Epoch 293/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2157 - accuracy: 0.3074 - val_loss: 0.2200 - val_accuracy: 0.4310
# Epoch 294/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2154 - accuracy: 0.3030 - val_loss: 0.2197 - val_accuracy: 0.4310
# Epoch 295/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2151 - accuracy: 0.3117 - val_loss: 0.2195 - val_accuracy: 0.4310
# Epoch 296/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2148 - accuracy: 0.3117 - val_loss: 0.2193 - val_accuracy: 0.4483
# Epoch 297/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2145 - accuracy: 0.3117 - val_loss: 0.2192 - val_accuracy: 0.4483
# Epoch 298/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2142 - accuracy: 0.3074 - val_loss: 0.2189 - val_accuracy: 0.4310
# Epoch 299/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2139 - accuracy: 0.3117 - val_loss: 0.2184 - val_accuracy: 0.4138
# Epoch 300/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2135 - accuracy: 0.3074 - val_loss: 0.2180 - val_accuracy: 0.4310

# %% [markdown]
# Como podemos comprobar el modelo de aprendizaje llega a unos valores de pérdida relativamente bajos en función de los epoch realizados.

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Pérdida en entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida en validación')
plt.title('Curva de pérdida durante el entrenamiento')
plt.xlabel('Epoch')
plt.ylabel('Pérdida')
#plt.yticks([0, 1], [0,1])
plt.legend()
plt.show()

# %% [markdown]
# ## Aciertos y fallos
# Una vez el modelo ha aprendido correctamente los datos es momento de ver los fallos y aciertos en el modelo, para de este modo asegurarnos que el aprendizaje ha sido correcto.

# %%
# Calcular el error de reconstrucción en el conjunto de prueba
X_test_pred = autoencoder.predict(X_test_norm)
test_reconstruction_errors = np.mean(np.power(X_test_norm - X_test_pred,2), axis=1)
umbral_fijo= 0.7
y_pred = [1 if e < umbral_fijo else 0 for e in test_reconstruction_errors]
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print('Precisión:', precision_score(y_test, y_pred))
print('Exhaustividad:', recall_score(y_test, y_pred))
print('F1-score:', f1_score(y_test, y_pred))
print('Exactitud:', accuracy_score(y_test, y_pred))
# Out:
# Precisión: 0.9710144927536232
# Exhaustividad: 0.9852941176470589
# F1-score: 0.9781021897810219
# Exactitud: 0.9620253164556962

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Crear el mapa de calor
plt.figure(figsize=(10,7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[ 9  2]
#  [ 1 67]]

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, umbral = precision_recall_curve(y_test, test_reconstruction_errors)

# %%
plt.plot(umbral, precision[1:], label="Precision",linewidth=5)
plt.plot(umbral, recall[1:], label="Recall",linewidth=5)
plt.title('Precision y Recall para diferentes umbrales')
plt.xlabel('Umbral')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Calcular la Curva ROC y el Área Bajo la Curva (AUC)
fpr, tpr, thresholds = roc_curve(y_test, test_reconstruction_errors, pos_label=0)  # Asumiendo que la clase 0 es de datos anómalos

# Calcular el área bajo la curva ROC
roc_auc = auc(fpr, tpr)

# Dibujar la curva ROC
plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
from IPython.core.display import HTML

HTML("""
<style>
.prompt {
    display: none;
}
</style>
""")
# Out:
# <style>
# .prompt {
#     display: none;
# }
# </style>

# %%
from IPython.core.display import HTML
HTML("<style>.rendered_html { font-size: 18px; }</style>")
# Out:
# <style>.rendered_html { font-size: 18px; }</style>

# %%
from IPython.core.display import HTML

HTML("""
<style>
.CodeMirror {
    font-size: 18px;
}
</style>
""")
# Out:
# <style>
# .CodeMirror {
#     font-size: 18px;
# }
# </style>

# %%
import pandas as pd

data = {
    'radius_mean': [17.99, 20.57, 19.69, 11.42, 20.29],
    'texture_mean': [10.38, 17.77, 21.25, 20.38, 14.34],
    'perimeter_mean': [122.8, 132.9, 130, 77.58, 135.1],
    'area_mean': [1001, 1326, 1203, 386.1, 1297],
    'smoothness_mean': [0.1184, 0.08474, 0.1096, 0.1425, 0.1003],
    'compactness_mean': [0.2776, 0.07864, 0.1599, 0.2839, 0.1328],
    'concavity_mean': [0.3001, 0.0869, 0.1974, 0.2414, 0.198],
    'concave_points_mean': [0.1471, 0.07017, 0.1279, 0.1052, 0.1043],
    'symmetry_mean': [0.2419, 0.1812, 0.2069, 0.2597, 0.1809],
    'fractal_dimension_mean': [0.07871, 0.05667, 0.05999, 0.09744, 0.05883],
    'radius_se': [1.095, 0.5435, 0.7456, 0.4956, 0.7572],
    'texture_se': [0.9053, 0.7339, 0.7869, 1.156, 0.7813],
    'perimeter_se': [8.589, 3.398, 4.585, 3.445, 5.438],
    'area_se': [153.4, 74.08, 94.03, 27.23, 94.44],
    'smoothness_se': [0.006399, 0.005225, 0.00615, 0.00911, 0.01149],
    'compactness_se': [0.04904, 0.01308, 0.04006, 0.07458, 0.02461],
    'concavity_se': [0.05373, 0.0186, 0.03832, 0.05661, 0.05688],
    'concave_points_se': [0.01587, 0.0134, 0.02058, 0.01867, 0.01885],
    'symmetry_se': [0.03003, 0.01389, 0.0225, 0.05963, 0.01756],
    'fractal_dimension_se': [0.006193, 0.003532, 0.004571, 0.009208, 0.005115],
    'radius_worst': [25.38, 24.99, 23.57, 14.91, 22.54],
    'texture_worst': [17.33, 23.41, 25.53, 26.5, 16.67],
    'perimeter_worst': [184.6, 158.8, 152.5, 98.87, 152.2],
    'area_worst': [2019, 1956, 1709, 567.7, 1575],
    'smoothness_worst': [0.1622, 0.1238, 0.1444, 0.2098, 0.1374],
    'compactness_worst': [0.6656, 0.1866, 0.4245, 0.8663, 0.205],
    'concavity_worst': [0.7119, 0.2416, 0.4504, 0.6869, 0.4],
    'concave_points_worst': [0.2654, 0.186, 0.243, 0.2575, 0.1625],
    'symmetry_worst': [0.4601,0.275,0.3613,0.6638,0.2364],
    'fractal_dimension_worst': [0.1189,0.08902,0.08758,0.173,0.07678],
                       }

# Crear el DataFrame
df = pd.DataFrame(data)

# Guardar el DataFrame como un archivo Excel
df.to_excel('WDBC2_Example_Data.xlsx', index=False)

# %% [markdown]
# # Experimentos del mismo modelo con Machine Learning
# Se realizarán diferentes predicciones con otros modelos para poder ver la comparación en su funcionamiento bajo las mismas condiciones que nuestro modelo Autoencoder.

# %%
from sklearn.neighbors import KNeighborsClassifier
Xn_train = X_train_clase_1
Xn_test = X_test_norm
y_check = y_train[y_train == 1]
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(Xn_train, y_check ) #Ajuste del modelo
pridct_Knn = knn.predict(X_test_norm)
print("Tasa de aciertos de Knn: {:.2f}".format(knn.score(X_test_norm, y_test)))
# Out:
# Tasa de aciertos de Knn: 0.86

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=2).fit(Xn_train, y_check)
pred_tree = tree.predict(Xn_test)
print("Tasa de acierto del árbol de decisión: {:.2f}".format(tree.score(Xn_test, y_test)))
# Out:
# Tasa de acierto del árbol de decisión: 0.86

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50,max_features=8).fit(Xn_train, y_check)
predict_random_forests = rf.predict(Xn_test)
print("Tasa de aciertos de random forest: {:.2f}".format(rf.score(Xn_test, y_test)))
# Out:
# Tasa de aciertos de random forest: 0.86

# %% [markdown]
# Debido a que estamos intentando clasificar utilizando exclusivamente una sola muestra no podemos utilizar SVC, ya que no hay frontera de decisión posible cuando solo hay 1 sola clase en el entrenamiento.

# %%
#from sklearn.svm import SVC
#svm = SVC(gamma=0.001, C=10)
#svm.fit(X_train_clase_1, y_check)
#print("Tasa de aciertos de SVM: {:.2f}".format(svm.score(Xn_test, y_test)))

# %% [markdown]
# Podemos ver que los 3 modelos utilizamos tienen exactamente los mismos datos ya que al carecer muestras de clase Maligna no son capaces de clasificar estas mismas.

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# Evaluación del mejor modelo de KNN
print("\n\nInforme de clasificación KNN")
y_pred_knn = knn.predict(Xn_test)
print(classification_report(y_test, y_pred_knn))


# Evaluación del mejor modelo de Random Forest
print("\n\nInforme de clasificación random forest")
y_pred_rf = rf.predict(Xn_test)
print(classification_report(y_test, y_pred_rf))


# Evaluación del mejor modelo de Random Forest
print("\n\nInforme de clasificación Árbol de decisión")
y_pred_svc = tree.predict(Xn_test)
print(classification_report(y_test, y_pred_svc))
#print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Informe de clasificación KNN
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        11
#          1.0       0.86      1.00      0.93        68
#
#     accuracy                           0.86        79
#    macro avg       0.43      0.50      0.46        79
# weighted avg       0.74      0.86      0.80        79
#
#
#
# Informe de clasificación random forest
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        11
#          1.0       0.86      1.00      0.93        68
#
#     accuracy                           0.86        79
#    macro avg       0.43      0.50      0.46        79
# weighted avg       0.74      0.86      0.80        79
#
#
#
# Informe de clasificación Árbol de decisión
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        11
#          1.0       0.86      1.00      0.93        68
#
#     accuracy                           0.86        79
#    macro avg       0.43      0.50      0.46        79
# weighted avg       0.74      0.86      0.80        79
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Todos estos errores son debidos a que los diferentes modelos de Machine Learning no han aprendido a clasificar correctamente, por lo que varios de sus valores obtenidos, como el de precisión, dan como resultado 0, que da problemas con las diferentes divisiones que se realizan en otras estadísticas.
#
# Para poder contemplarlo mejor vemos aquí la matriz de confusión.

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred_rf)
print(conf_matrix)
# Crear el mapa de calor
plt.figure(figsize=(10,7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[ 0 11]
#  [ 0 68]]

# %% [markdown]
# Como vemos nos acabamos de cerciorar de que los modelos están clasificando todas las muestras posibles como benignas, ya que no conocen el patrón de las malignas.

# %% [markdown]
# #
